# %% [markdown]
# # Market Research

# %%
import pandas as pd
from data.sample_data import load_ohlcv
df = load_ohlcv('SAMPLE','2018-01-01','2024-12-31')
monthly = df['Close'].pct_change().resample('M').apply(lambda x:(1+x).prod()-1)
monthly.describe()
